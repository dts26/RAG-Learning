# %%
import pandas as pd
from src.chunker import (
    chunk_csv,
    _fmt_appendix1,
    _meta_appendix1,
)
# 1. Load + pre-process
df = pd.read_csv("rag_data/appendix1_questionnairemasterandscoring.csv", sep=";", encoding="latin-1", dtype={"no": str})
df["answer"] = df["answer"].astype(str).str.replace("?", "≤", regex=False)
# 2. Chunk

chunks = chunk_csv(df, "no", source="csv_appendix1", chunk_type="question", format_fn=_fmt_appendix1, metadata_fn=_meta_appendix1)
print(chunks[0]['content'])
print(chunks[0]['metadata'])
# Out:
# Question 1.1 — Types of higher education institution
# Category: Setting and Infrastructure (SI)
# Evidence Required: No
# Indicator Code: Not Available
# Max Score: Not Available
# Colored: Not Available
# Options:
# [1] Comprehensive (Calculated score: Not Available)
# [2] Specialized higher education institution (Calculated score: Not Available)
#
# {'category': 'Setting and Infrastructure (SI)', 'question_no': '1.1', 'evidence_required': 'No', 'max_score': -1.0, 'colored': 'Not Available', 'source': 'csv_appendix1', 'chunk_type': 'question'}
